# %%
import gymnasium as gym
from gymnasium import ObservationWrapper, RewardWrapper
import pandas as pd

# %%
env = gym.make('FrozenLake-v1', desc=None, map_name="4x4", is_slippery=True, render_mode="human")

# %%
def interact_with_env(env) -> 'pd.DataFrame':    
    l_obs = []
    l_action = []
    l_next_obs = []
    l_reward = []
    l_terminated = []
    l_truncated = []
    
    observation, info = env.reset(seed=42)
    for _ in range(80):
       l_obs.append(observation)
       action = env.action_space.sample() # # policy(observation)  # User-defined policy function
       l_action.append(action) 
       observation, reward, terminated, truncated, info = env.step(action)
       l_next_obs.append(observation)
       l_reward.append(reward)
       l_terminated.append(terminated)
       l_truncated.append(truncated)
        
       if terminated or truncated:
          observation, info = env.reset()

    return pd.DataFrame({
        'obs': l_obs,
        'action': l_action,
        'next_obs': l_next_obs,
        'reward': l_reward,
        'terminated': l_terminated,
        'truncated': l_truncated,
    })

# %%
df = interact_with_env(env)

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_d2a5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2a5b_level0_col0" class="col_heading level0 col0" >obs</th>
#       <th id="T_d2a5b_level0_col1" class="col_heading level0 col1" >action</th>
#       <th id="T_d2a5b_level0_col2" class="col_heading level0 col2" >next_obs</th>
#       <th id="T_d2a5b_level0_col3" class="col_heading level0 col3" >reward</th>
#       <th id="T_d2a5b_level0_col4" class="col_heading level0 col4" >terminated</th>
#       <th id="T_d2a5b_level0_col5" class="col_heading level0 col5" >truncated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2a5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2a5b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d2a5b_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_d2a5b_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_d2a5b_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_d2a5b_row0_col4" class="data row0 col4" >False</td>
#       <td id="T_d2a5b_row0_col5" class="data row0 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2a5b_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_d2a5b_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_d2a5b_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_d2a5b_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_d2a5b_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_d2a5b_row1_col5" class="data row1 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2a5b_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_d2a5b_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_d2a5b_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_d2a5b_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_d2a5b_row2_col4" class="data row2 col4" >False</td>
#       <td id="T_d2a5b_row2_col5" class="data row2 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2a5b_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_d2a5b_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_d2a5b_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_d2a5b_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_d2a5b_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_d2a5b_row3_col5" class="data row3 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2a5b_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_d2a5b_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_d2a5b_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_d2a5b_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_d2a5b_row4_col4" class="data row4 col4" >False</td>
#       <td id="T_d2a5b_row4_col5" class="data row4 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2a5b_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_d2a5b_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_d2a5b_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_d2a5b_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_d2a5b_row5_col4" class="data row5 col4" >False</td>
#       <td id="T_d2a5b_row5_col5" class="data row5 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d2a5b_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_d2a5b_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_d2a5b_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_d2a5b_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_d2a5b_row6_col4" class="data row6 col4" >False</td>
#       <td id="T_d2a5b_row6_col5" class="data row6 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d2a5b_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_d2a5b_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_d2a5b_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_d2a5b_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_d2a5b_row7_col4" class="data row7 col4" >False</td>
#       <td id="T_d2a5b_row7_col5" class="data row7 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d2a5b_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_d2a5b_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_d2a5b_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_d2a5b_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_d2a5b_row8_col4" class="data row8 col4" >False</td>
#       <td id="T_d2a5b_row8_col5" class="data row8 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d2a5b_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_d2a5b_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_d2a5b_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_d2a5b_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_d2a5b_row9_col4" class="data row9 col4" >True</td>
#       <td id="T_d2a5b_row9_col5" class="data row9 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d2a5b_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_d2a5b_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_d2a5b_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_d2a5b_row10_col3" class="data row10 col3" >0.000000</td>
#       <td id="T_d2a5b_row10_col4" class="data row10 col4" >False</td>
#       <td id="T_d2a5b_row10_col5" class="data row10 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d2a5b_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_d2a5b_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_d2a5b_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_d2a5b_row11_col3" class="data row11 col3" >0.000000</td>
#       <td id="T_d2a5b_row11_col4" class="data row11 col4" >False</td>
#       <td id="T_d2a5b_row11_col5" class="data row11 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d2a5b_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_d2a5b_row12_col1" class="data row12 col1" >3</td>
#       <td id="T_d2a5b_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_d2a5b_row12_col3" class="data row12 col3" >0.000000</td>
#       <td id="T_d2a5b_row12_col4" class="data row12 col4" >False</td>
#       <td id="T_d2a5b_row12_col5" class="data row12 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d2a5b_row13_col0" class="data row13 col0" >1</td>
#       <td id="T_d2a5b_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_d2a5b_row13_col2" class="data row13 col2" >1</td>
#       <td id="T_d2a5b_row13_col3" class="data row13 col3" >0.000000</td>
#       <td id="T_d2a5b_row13_col4" class="data row13 col4" >False</td>
#       <td id="T_d2a5b_row13_col5" class="data row13 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a5b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d2a5b_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_d2a5b_row14_col1" class="data row14 col1" >0</td>
#       <td id="T_d2a5b_row14_col2" class="data row14 col2" >0</td>
#       <td id="T_d2a5b_row14_col3" class="data row14 col3" >0.000000</td>
#       <td id="T_d2a5b_row14_col4" class="data r

# %%
#env.close()

# %%
env.observation_space
# Out:
# Discrete(16)

# %%
env.action_space
# Out:
# Discrete(4)

# %%
class CartesianObservationWrapper(ObservationWrapper):
    def __init__(self, env: gym.Env):
        super().__init__(env)

    def observation(self, observation):
        row = observation // 4
        col = observation % 4
        return row, col

    @property
    def observation_space(self):
        return gym.spaces.Tuple((gym.spaces.Discrete(4), gym.spaces.Discrete(4)))

# %%
cartesian_env = CartesianObservationWrapper(env)

# %%
obs, info = cartesian_env.reset(seed=42)

# %%
info
# Out:
# {'prob': 1}

# %%
obs
# Out:
# (0, 0)

# %%
cartesian_env.observation_space
# Out:
# Tuple(Discrete(4), Discrete(4))

# %%
cartesian_env.observation_space.sample()
# Out:
# (np.int64(0), np.int64(3))

# %%
df = interact_with_env(cartesian_env)

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_9d8b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d8b2_level0_col0" class="col_heading level0 col0" >obs</th>
#       <th id="T_9d8b2_level0_col1" class="col_heading level0 col1" >action</th>
#       <th id="T_9d8b2_level0_col2" class="col_heading level0 col2" >next_obs</th>
#       <th id="T_9d8b2_level0_col3" class="col_heading level0 col3" >reward</th>
#       <th id="T_9d8b2_level0_col4" class="col_heading level0 col4" >terminated</th>
#       <th id="T_9d8b2_level0_col5" class="col_heading level0 col5" >truncated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d8b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d8b2_row0_col0" class="data row0 col0" >(0, 0)</td>
#       <td id="T_9d8b2_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_9d8b2_row0_col2" class="data row0 col2" >(0, 0)</td>
#       <td id="T_9d8b2_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_9d8b2_row0_col4" class="data row0 col4" >False</td>
#       <td id="T_9d8b2_row0_col5" class="data row0 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d8b2_row1_col0" class="data row1 col0" >(0, 0)</td>
#       <td id="T_9d8b2_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_9d8b2_row1_col2" class="data row1 col2" >(1, 0)</td>
#       <td id="T_9d8b2_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_9d8b2_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_9d8b2_row1_col5" class="data row1 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d8b2_row2_col0" class="data row2 col0" >(1, 0)</td>
#       <td id="T_9d8b2_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_9d8b2_row2_col2" class="data row2 col2" >(1, 0)</td>
#       <td id="T_9d8b2_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_9d8b2_row2_col4" class="data row2 col4" >False</td>
#       <td id="T_9d8b2_row2_col5" class="data row2 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d8b2_row3_col0" class="data row3 col0" >(1, 0)</td>
#       <td id="T_9d8b2_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_9d8b2_row3_col2" class="data row3 col2" >(2, 0)</td>
#       <td id="T_9d8b2_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_9d8b2_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_9d8b2_row3_col5" class="data row3 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9d8b2_row4_col0" class="data row4 col0" >(2, 0)</td>
#       <td id="T_9d8b2_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_9d8b2_row4_col2" class="data row4 col2" >(1, 0)</td>
#       <td id="T_9d8b2_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_9d8b2_row4_col4" class="data row4 col4" >False</td>
#       <td id="T_9d8b2_row4_col5" class="data row4 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9d8b2_row5_col0" class="data row5 col0" >(1, 0)</td>
#       <td id="T_9d8b2_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_9d8b2_row5_col2" class="data row5 col2" >(1, 0)</td>
#       <td id="T_9d8b2_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_9d8b2_row5_col4" class="data row5 col4" >False</td>
#       <td id="T_9d8b2_row5_col5" class="data row5 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9d8b2_row6_col0" class="data row6 col0" >(1, 0)</td>
#       <td id="T_9d8b2_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_9d8b2_row6_col2" class="data row6 col2" >(1, 1)</td>
#       <td id="T_9d8b2_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_9d8b2_row6_col4" class="data row6 col4" >True</td>
#       <td id="T_9d8b2_row6_col5" class="data row6 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9d8b2_row7_col0" class="data row7 col0" >(0, 0)</td>
#       <td id="T_9d8b2_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_9d8b2_row7_col2" class="data row7 col2" >(0, 1)</td>
#       <td id="T_9d8b2_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_9d8b2_row7_col4" class="data row7 col4" >False</td>
#       <td id="T_9d8b2_row7_col5" class="data row7 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9d8b2_row8_col0" class="data row8 col0" >(0, 1)</td>
#       <td id="T_9d8b2_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_9d8b2_row8_col2" class="data row8 col2" >(1, 1)</td>
#       <td id="T_9d8b2_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_9d8b2_row8_col4" class="data row8 col4" >True</td>
#       <td id="T_9d8b2_row8_col5" class="data row8 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9d8b2_row9_col0" class="data row9 col0" >(0, 0)</td>
#       <td id="T_9d8b2_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_9d8b2_row9_col2" class="data row9 col2" >(0, 1)</td>
#       <td id="T_9d8b2_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_9d8b2_row9_col4" class="data row9 col4" >False</td>
#       <td id="T_9d8b2_row9_col5" class="data row9 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9d8b2_row10_col0" class="data row10 col0" >(0, 1)</td>
#       <td id="T_9d8b2_row10_col1" class="data row10 col1" >3</td>
#       <td id="T_9d8b2_row10_col2" class="data row10 col2" >(0, 0)</td>
#       <td id="T_9d8b2_row10_col3" class="data row10 col3" >0.000000</td>
#       <td id="T_9d8b2_row10_col4" class="data row10 col4" >False</td>
#       <td id="T_9d8b2_row10_col5" class="data row10 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9d8b2_row11_col0" class="data row11 col0" >(0, 0)</td>
#       <td id="T_9d8b2_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_9d8b2_row11_col2" class="data row11 col2" >(0, 0)</td>
#       <td id="T_9d8b2_row11_col3" class="data row11 col3" >0.000000</td>
#       <td id="T_9d8b2_row11_col4" class="data row11 col4" >False</td>
#       <td id="T_9d8b2_row11_col5" class="data row11 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9d8b2_row12_col0" class="data row12 col0" >(0, 0)</td>
#       <td id="T_9d8b2_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_9d8b2_row12_col2" class="data row12 col2" >(1, 0)</td>
#       <td id="T_9d8b2_row12_col3" class="data row12 col3" >0.000000</td>
#       <td id="T_9d8b2_row12_col4" class="data row12 col4" >False</td>
#       <td id="T_9d8b2_row12_col5" class="data row12 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9d8b2_row13_col0" class="data row13 col0" >(1, 0)</td>
#       <td id="T_9d8b2_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_9d8b2_row13_col2" class="data row13 col2" >(1, 1)</td>
#       <td id="T_9d8b2_row13_col3" class="data row13 col3" >0.000000</td>
#       <td id="T_9d8b2_row13_col4" class="data row13 col4" >True</td>
#       <td id="T_9d8b2_row13_col5" class="data row13 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d8b2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9d8b2_row14_col0" class="data row14 col0" >(0, 0)</td>
#       <td id="T_9d8b2_row14_col1" class="data row14 col1" >3</td>
#       <td id="T_9d8b2_row14_col2" class="da

# %%
class ManhattanDistanceRewardWrapper(RewardWrapper):
    def __init__(self, env: gym.Env):
        super().__init__(env)
        self.current_obs = None

    def reward(self, reward):
        manhattan_distance = (3 - self.current_obs[0]) + (3 - self.current_obs[1])
        return reward * 100 - manhattan_distance 

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self.current_obs = obs
        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        self.current_obs = obs
        return obs, self.reward(reward), terminated, truncated, info

# %%
md_env = ManhattanDistanceRewardWrapper(cartesian_env)

# %%
df = interact_with_env(md_env)

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_6f4de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f4de_level0_col0" class="col_heading level0 col0" >obs</th>
#       <th id="T_6f4de_level0_col1" class="col_heading level0 col1" >action</th>
#       <th id="T_6f4de_level0_col2" class="col_heading level0 col2" >next_obs</th>
#       <th id="T_6f4de_level0_col3" class="col_heading level0 col3" >reward</th>
#       <th id="T_6f4de_level0_col4" class="col_heading level0 col4" >terminated</th>
#       <th id="T_6f4de_level0_col5" class="col_heading level0 col5" >truncated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f4de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f4de_row0_col0" class="data row0 col0" >(0, 0)</td>
#       <td id="T_6f4de_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_6f4de_row0_col2" class="data row0 col2" >(0, 0)</td>
#       <td id="T_6f4de_row0_col3" class="data row0 col3" >-6.000000</td>
#       <td id="T_6f4de_row0_col4" class="data row0 col4" >False</td>
#       <td id="T_6f4de_row0_col5" class="data row0 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f4de_row1_col0" class="data row1 col0" >(0, 0)</td>
#       <td id="T_6f4de_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_6f4de_row1_col2" class="data row1 col2" >(1, 0)</td>
#       <td id="T_6f4de_row1_col3" class="data row1 col3" >-5.000000</td>
#       <td id="T_6f4de_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_6f4de_row1_col5" class="data row1 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6f4de_row2_col0" class="data row2 col0" >(1, 0)</td>
#       <td id="T_6f4de_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_6f4de_row2_col2" class="data row2 col2" >(2, 0)</td>
#       <td id="T_6f4de_row2_col3" class="data row2 col3" >-4.000000</td>
#       <td id="T_6f4de_row2_col4" class="data row2 col4" >False</td>
#       <td id="T_6f4de_row2_col5" class="data row2 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6f4de_row3_col0" class="data row3 col0" >(2, 0)</td>
#       <td id="T_6f4de_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_6f4de_row3_col2" class="data row3 col2" >(2, 0)</td>
#       <td id="T_6f4de_row3_col3" class="data row3 col3" >-4.000000</td>
#       <td id="T_6f4de_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_6f4de_row3_col5" class="data row3 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6f4de_row4_col0" class="data row4 col0" >(2, 0)</td>
#       <td id="T_6f4de_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_6f4de_row4_col2" class="data row4 col2" >(1, 0)</td>
#       <td id="T_6f4de_row4_col3" class="data row4 col3" >-5.000000</td>
#       <td id="T_6f4de_row4_col4" class="data row4 col4" >False</td>
#       <td id="T_6f4de_row4_col5" class="data row4 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6f4de_row5_col0" class="data row5 col0" >(1, 0)</td>
#       <td id="T_6f4de_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_6f4de_row5_col2" class="data row5 col2" >(0, 0)</td>
#       <td id="T_6f4de_row5_col3" class="data row5 col3" >-6.000000</td>
#       <td id="T_6f4de_row5_col4" class="data row5 col4" >False</td>
#       <td id="T_6f4de_row5_col5" class="data row5 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6f4de_row6_col0" class="data row6 col0" >(0, 0)</td>
#       <td id="T_6f4de_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_6f4de_row6_col2" class="data row6 col2" >(1, 0)</td>
#       <td id="T_6f4de_row6_col3" class="data row6 col3" >-5.000000</td>
#       <td id="T_6f4de_row6_col4" class="data row6 col4" >False</td>
#       <td id="T_6f4de_row6_col5" class="data row6 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6f4de_row7_col0" class="data row7 col0" >(1, 0)</td>
#       <td id="T_6f4de_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_6f4de_row7_col2" class="data row7 col2" >(2, 0)</td>
#       <td id="T_6f4de_row7_col3" class="data row7 col3" >-4.000000</td>
#       <td id="T_6f4de_row7_col4" class="data row7 col4" >False</td>
#       <td id="T_6f4de_row7_col5" class="data row7 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6f4de_row8_col0" class="data row8 col0" >(2, 0)</td>
#       <td id="T_6f4de_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_6f4de_row8_col2" class="data row8 col2" >(2, 0)</td>
#       <td id="T_6f4de_row8_col3" class="data row8 col3" >-4.000000</td>
#       <td id="T_6f4de_row8_col4" class="data row8 col4" >False</td>
#       <td id="T_6f4de_row8_col5" class="data row8 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6f4de_row9_col0" class="data row9 col0" >(2, 0)</td>
#       <td id="T_6f4de_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_6f4de_row9_col2" class="data row9 col2" >(2, 1)</td>
#       <td id="T_6f4de_row9_col3" class="data row9 col3" >-3.000000</td>
#       <td id="T_6f4de_row9_col4" class="data row9 col4" >False</td>
#       <td id="T_6f4de_row9_col5" class="data row9 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6f4de_row10_col0" class="data row10 col0" >(2, 1)</td>
#       <td id="T_6f4de_row10_col1" class="data row10 col1" >3</td>
#       <td id="T_6f4de_row10_col2" class="data row10 col2" >(2, 0)</td>
#       <td id="T_6f4de_row10_col3" class="data row10 col3" >-4.000000</td>
#       <td id="T_6f4de_row10_col4" class="data row10 col4" >False</td>
#       <td id="T_6f4de_row10_col5" class="data row10 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6f4de_row11_col0" class="data row11 col0" >(2, 0)</td>
#       <td id="T_6f4de_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_6f4de_row11_col2" class="data row11 col2" >(2, 1)</td>
#       <td id="T_6f4de_row11_col3" class="data row11 col3" >-3.000000</td>
#       <td id="T_6f4de_row11_col4" class="data row11 col4" >False</td>
#       <td id="T_6f4de_row11_col5" class="data row11 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6f4de_row12_col0" class="data row12 col0" >(2, 1)</td>
#       <td id="T_6f4de_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_6f4de_row12_col2" class="data row12 col2" >(2, 2)</td>
#       <td id="T_6f4de_row12_col3" class="data row12 col3" >-2.000000</td>
#       <td id="T_6f4de_row12_col4" class="data row12 col4" >False</td>
#       <td id="T_6f4de_row12_col5" class="data row12 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6f4de_row13_col0" class="data row13 col0" >(2, 2)</td>
#       <td id="T_6f4de_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_6f4de_row13_col2" class="data row13 col2" >(2, 1)</td>
#       <td id="T_6f4de_row13_col3" class="data row13 col3" >-3.000000</td>
#       <td id="T_6f4de_row13_col4" class="data row13 col4" >False</td>
#       <td id="T_6f4de_row13_col5" class="data row13 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f4de_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6f4de_row14_col0" class="data row14 col0" >(2, 1)</td>
#       <td id="T_6f4de_row14_col1" class="data row14 col1" >2</td>
#       <td id="T_6f4de_row1
